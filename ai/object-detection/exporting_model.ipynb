# %%
# !git clone https://github.com/zzh8829/yolov3-tf2
# %cd yolov3-tf2/
# !pip install -r requirements-gpu.txt
# Out:
# /home/elice/ai-project/ai/object-detection/yolov3-tf2
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///home/elice/ai-project/ai/object-detection/yolov3-tf2 (from -r requirements-gpu.txt (line 6))
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow-gpu==2.5.1 in /home/elice/.local/lib/python3.8/site-packages (from -r requirements-gpu.txt (line 1)) (2.5.1)
# Requirement already satisfied: opencv-python==4.2.0.32 in /home/elice/.local/lib/python3.8/site-packages (from -r requirements-gpu.txt (line 2)) (4.2.0.32)
# Requirement already satisfied: lxml in /home/elice/.local/lib/python3.8/site-packages (from -r requirements-gpu.txt (line 3)) (4.9.0)
# Requirement already satisfied: tqdm in /home/elice/.local/lib/python3.8/site-packages (from -r requirements-gpu.txt (line 4)) (4.64.0)
# Requirement already satisfied: absl-py~=0.10 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (0.15.0)
# Requirement already satisfied: termcolor~=1.1.0 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.1.0)
# Requirement already satisfied: tensorboard~=2.5 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (2.8.0)
# Requirement already satisfied: google-pasta~=0.2 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (0.2.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (3.3.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (3.7.4.3)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wrapt~=1.12.1 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.12.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.12)
# Collecting numpy~=1.19.2
#   Using cached numpy-1.19.5-cp38-cp38-manylinux2010_x86_64.whl (14.9 MB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: wheel~=0.35 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (0.37.1)
# Requirement already satisfied: astunparse~=1.6.3 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (3.19.4)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (2.5.0.dev2021032900)
# Requirement already satisfied: grpcio~=1.34.0 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.34.1)
# Collecting h5py~=3.1.0
#   Using cached h5py-3.1.0-cp38-cp38-manylinux1_x86_64.whl (4.4 MB)
# Requirement already satisfied: six~=1.15.0 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.15.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /home/elice/.local/lib/python3.8/site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.1.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/elice/.local/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (2.28.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/elice/.local/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (2.1.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/elice/.local/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/elice/.local/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/elice/.local/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/elice/.local/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (62.3.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/elice/.local/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (2.7.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/elice/.local/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (3.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/elice/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/elice/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/elice/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/elice/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/elice/.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (4.11.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/elice/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/elice/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/elice/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/elice/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.26.9)
# Requirement already satisfied: zipp>=0.5 in /home/elice/.local/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/elice/.local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/elice/.local/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (3.2.0)
# Installing collected packages: yolov3-tf2, tensorflow-estimator, numpy, gast, h5py
#   Attempting uninstall: yolov3-tf2
#     Found existing installation: yolov3-tf2 0.1
#     Uninstalling yolov3-tf2-0.1:
#       Successfully uninstalled yolov3-tf2-0.1
#   Running setup.py develop for yolov3-tf2
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Attempting uninstall: gast
#     Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-nightly 2.10.0.dev20220611 requires absl-py>=1.0.0, but you have absl-py 0.15.0 which is incompatible.
# tf-nightly 2.10.0.dev20220611 requires keras-nightly~=2.10.0.dev, but you have keras-nightly 2.5.0.dev2021032900 which is incompatible.
# tf-nightly 2.10.0.dev20220611 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# tensorflow 2.3.0 requires gast==0.3.3, but you have gast 0.4.0 which is incompatible.
# tensorflow 2.3.0 requires h5py<2.11.0,>=2.10.0, but you have h5py 3.1.0 which is incompatible.
# tensorflow 2.3.0 requires numpy<1.19.0,>=1.16.0, but you have numpy 1.19.5 which is incompatible.
# tensorflow 2.3.0 requires tensorflow-estimator<2.4.0,>=2.3.0, but you have tensorflow-estimator 2.5.0 which is incompatible.
# Successfully installed gast-0.4.0 h5py-3.1.0 numpy-1.19.5 tensorflow-estimator-2.5.0 yolov3-tf2-0.1

# %%
# !ls

import tensorflow as tf
tf.__version__
# Out:
# LICENSE		 conda-gpu.yml	  docs			setup.py
# README.md	 convert.py	  output.jpg		tools
# checkpoints	 data		  requirements-gpu.txt	train.py
# colab_gpu.ipynb  detect.py	  requirements.txt	yolov3_tf2
# conda-cpu.yml	 detect_video.py  serving		yolov3_tf2.egg-info
# '2.3.0'

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O data/yolov3.weights
# !python3 convert.py
# Out:
# 2022-06-21 05:39:40.141972: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-06-21 05:39:40.142052: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-06-21 05:39:41.935731: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-06-21 05:39:41.970417: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-21 05:39:41.973189: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.61GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-06-21 05:39:41.973670: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-06-21 05:39:41.973891: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory
# 2022-06-21 05:39:42.032336: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-06-21 05:39:42.033166: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-06-21 05:39:42.033357: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory
# 2022-06-21 05:39:42.033472: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusparse.so.10'; dlerror: libcusparse.so.10: cannot open shared object file: No such file or directory
# 2022-06-21 05:39:42.033592: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory
# 2022-06-21 05:39:42.033619: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-06-21 05:39:42.049237: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-21 05:39:42.058559: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2000179999 Hz
# 2022-06-21 05:39:42.058917: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2a9bd70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-06-21 05:39:42.058964: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-06-21 05:39:42.060944: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-06-21 05:39:42.060992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# 2022-06-21 05:39:43.710025: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 18874368 exceeds 10% of free system memory.
# 2022-06-21 05:39:43.738478: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 18874368 exceeds 10% of free system memory.
# 2022-06-21 05:39:43.747967: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 18874368 exceeds 10% of free system memory.
# 2022-06-21 05:39:43.831634: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 18874368 exceeds 10% of free system memory.
# 2022-06-21 05:39:43.855615: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 18874368 exceeds 10% of free system memory.
# Model: "yolov3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None, None,  0
# __________________________________________________________________________________________________
# yolo_darknet (Functional)       ((None, None, None,  40620640    input[0][0]
# __________________________________________________________________________________________________
# yolo_conv_0 (Functional)        (None, None, None, 5 11024384    yolo_darknet[0][2]
# __________________________________________________________________________________________________
# yolo_conv_1 (Functional)        (None, None, None, 2 2957312     yolo_conv_0[0][0]
#                                                                  yolo_darknet[0][1]
# __________________________________________________________________________________________________
# yolo_conv_2 (Functional)        (None, None, None, 1 741376      yolo_conv_1[0][0]
#                                                                  yolo_darknet[0][0]
# __________________________________________________________________________________________________
# yolo_output_0 (Functional)      (None, None, None, 3 4984063     yolo_conv_0[0][0]
# __________________________________________________________________________________________________
# yolo_output_1 (Functional)      (None, None, None, 3 1312511     yolo_conv_1[0][0]
# __________________________________________________________________________________________________
# yolo_output_2 (Functional)      (None, None, None, 3 361471      yolo_conv_2[0][0]
# __________________________________________________________________________________________________
# yolo_boxes_0 (Lambda)           ((None, None, None,  0           yolo_output_0[0][0]
# __________________________________________________________________________________________________
# yolo_boxes_1 (Lambda)           ((None, None, None,  0           yolo_output_1[0][0]
# __________________________________________________________________________________________________
# yolo_boxes_2 (Lambda)           ((None, None, None,  0           yolo_output_2[0][0]
# __________________________________________________________________________________________________
# yolo_nms (Lambda)               ((1, None, 4), (1, N 0           yolo_boxes_0[0][0]
#                                                                  yolo_boxes_0[0][1]
#                                                                  yolo_boxes_0[0][2]
#                                                                  yolo_boxes_1[0][0]
#                                                                  yolo_boxes_1[0][1]
#                                                                  yolo_boxes_1[0][2]
#                                                                  yolo_boxes_2[0][0]
#                                                                  yolo_boxes_2[0][1]
#                                                                  yolo_boxes_2[0][2]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# I0621 05:39:47.317706 139900820113216 convert.py:24] model created
# I0621 05:39:47.319824 139900820113216 utils.py:44] yolo_darknet/conv2d bn
# I0621 05:39:47.321861 139900820113216 utils.py:44] yolo_darknet/conv2d_1 bn
# I0621 05:39:47.325291 139900820113216 utils.py:44] yolo_darknet/conv2d_2 bn
# I0621 05:39:47.327042 139900820113216 utils.py:44] yolo_darknet/conv2d_3 bn
# I0621 05:39:47.328880 139900820113216 utils.py:44] yolo_darknet/conv2d_4 bn
# I0621 05:39:47.332820 139900820113216 utils.py:44] yolo_darknet/conv2d_5 bn
# I0621 05:39:47.334709 139900820113216 utils.py:44] yolo_darknet/conv2d_6 bn
# I0621 05:39:47.338038 139900820113216 utils.py:44] yolo_darknet/conv2d_7 bn
# I0621 05:39:47.339941 139900820113216 utils.py:44] yolo_darknet/conv2d_8 bn
# I0621 05:39:47.342687 139900820113216 utils.py:44] yolo_darknet/conv2d_9 bn
# I0621 05:39:47.349659 139900820113216 utils.py:44] yolo_darknet/conv2d_10 bn
# I0621 05:39:47.351722 139900820113216 utils.py:44] yolo_darknet/conv2d_11 bn
# I0621 05:39:47.357476 139900820113216 utils.py:44] yolo_darknet/conv2d_12 bn
# I0621 05:39:47.358958 139900820113216 utils.py:44] yolo_darknet/conv2d_13 bn
# I0621 05:39:47.364772 139900820113216 utils.py:44] yolo_darknet/conv2d_14 bn
# I0621 05:39:47.366628 139900820113216 utils.py:44] yolo_darknet/conv2d_15 bn
# I0621 05:39:47.373703 139900820113216 utils.py:44] yolo_darknet/conv2d_16 bn
# I0621 05:39:47.375245 139900820113216 utils.py:44] yolo_darknet/conv2d_17 bn
# I0621 05:39:47.381044 139900820113216 utils.py:44] yolo_darknet/conv2d_18 bn
# I0621 05:39:47.382394 139900820113216 utils.py:44] yolo_darknet/conv2d_19 bn
# I0621 05:39:47.389293 139900820113216 utils.py:44] yolo_darknet/conv2d_20 bn
# I0621 05:39:47.391551 139900820113216 utils.py:44] yolo_darknet/conv2d_21 bn
# I0621 05:39:47.398547 139900820113216 utils.py:44] yolo_darknet/conv2d_22 bn
# I0621 05:39:47.400011 139900820113216 utils.py:44] yolo_darknet/conv2d_23 bn
# I0621 05:39:47.405873 139900820113216 utils.py:44] yolo_darknet/conv2d_24 bn
# I0621 05:39:47.408049 139900820113216 utils.py:44] yolo_darknet/conv2d_25 bn
# I0621 05:39:47.413723 139900820113216 utils.py:44] yolo_darknet/conv2d_26 bn
# I0621 05:39:47.434025 139900820113216 utils.py:44] yolo_darknet/conv2d_27 bn
# I0621 05:39:47.436769 139900820113216 utils.py:44] yolo_darknet/conv2d_28 bn
# I0621 05:39:47.454534 139900820113216 utils.py:44] yolo_darknet/conv2d_29 bn
# I0621 05:39:47.458736 139900820113216 utils.py:44] yolo_darknet/conv2d_30 bn
# I0621 05:39:47.481457 139900820113216 utils.py:44] yolo_darknet/conv2d_31 bn
# I0621 05:39:47.484966 139900820113216 utils.py:44] yolo_darknet/conv2d_32 bn
# I0621 05:39:47.505064 139900820113216 utils.py:44] yolo_darknet/conv2d_33 bn
# I0621 05:39:47.511330 139900820113216 utils.py:44] yolo_darknet/conv2d_34 bn
# I0621 05:39:47.532268 139900820113216 utils.py:44] yolo_darknet/conv2d_35 bn
# I0621 05:39:47.540879 139900820113216 utils.py:44] yolo_darknet/conv2d_36 bn
# I0621 05:39:47.562472 139900820113216 utils.py:44] yolo_darknet/conv2d_37 bn
# I0621 05:39:47.566332 139900820113216 utils.py:44] yolo_darknet/conv2d_38 bn
# I0621 05:39:47.586319 139900820113216 utils.py:44] yolo_darknet/conv2d_39 bn
# I0621 05:39:47.590115 139900820113216 utils.py:44] yolo_darknet/conv2d_40 bn
# I0621 05:39:47.610951 139900820113216 utils.py:44] yolo_darknet/conv2d_41 bn
# I0621 05:39:47.616552 139900820113216 utils.py:44] yolo_darknet/conv2d_42 bn
# I0621 05:39:47.641485 139900820113216 utils.py:44] yolo_darknet/conv2d_43 bn
# I0621 05:39:47.756504 139900820113216 utils.py:44] yolo_darknet/conv2d_44 bn
# I0621 05:39:47.769758 139900820113216 utils.py:44] yolo_darknet/conv2d_45 bn
# I0621 05:39:47.900176 139900820113216 utils.py:44] yolo_darknet/conv2d_46 bn
# I0621 05:39:47.910865 139900820113216 utils.py:44] yolo_darknet/conv2d_47 bn
# I0621 05:39:48.029645 139900820113216 utils.py:44] yolo_darknet/conv2d_48 bn
# I0621 05:39:48.044214 139900820113216 utils.py:44] yolo_darknet/conv2d_49 bn
# I0621 05:39:48.167988 139900820113216 utils.py:44] yolo_darknet/conv2d_50 bn
# I0621 05:39:48.178337 139900820113216 utils.py:44] yolo_darknet/conv2d_51 bn
# I0621 05:39:48.307471 139900820113216 utils.py:44] yolo_conv_0/conv2d_52 bn
# I0621 05:39:48.322321 139900820113216 utils.py:44] yolo_conv_0/conv2d_53 bn
# I0621 05:39:48.455355 139900820113216 utils.py:44] yolo_conv_0/conv2d_54 bn
# I0621 05:39:48.466548 139900820113216 utils.py:44] yolo_conv_0/conv2d_55 bn
# I0621 05:39:48.591276 139900820113216 utils.py:44] yolo_conv_0/conv2d_56 bn
# I0621 05:39:48.603034 139900820113216 utils.py:44] yolo_output_0/conv2d_57 bn
# I0621 05:39:48.727372 139900820113216 utils.py:44] yolo_output_0/conv2d_58 bias
# I0621 05:39:48.732477 139900820113216 utils.py:44] yolo_conv_1/conv2d_59 bn
# I0621 05:39:48.737547 139900820113216 utils.py:44] yolo_conv_1/conv2d_60 bn
# I0621 05:39:48.741777 139900820113216 utils.py:44] yolo_conv_1/conv2d_61 bn
# I0621 05:39:48.765519 139900820113216 utils.py:44] yolo_conv_1/conv2d_62 bn
# I0621 05:39:48.768504 139900820113216 utils.py:44] yolo_conv_1/conv2d_63 bn
# I0621 05:39:48.790623 139900820113216 utils.py:44] yolo_conv_1/conv2d_64 bn
# I0621 05:39:48.794167 139900820113216 utils.py:44] yolo_output_1/conv2d_65 bn
# I0621 05:39:48.819959 139900820113216 utils.py:44] yolo_output_1/conv2d_66 bias
# I0621 05:39:48.822460 139900820113216 utils.py:44] yolo_conv_2/conv2d_67 bn
# I0621 05:39:48.824146 139900820113216 utils.py:44] yolo_conv_2/conv2d_68 bn
# I0621 05:39:48.825899 139900820113216 utils.py:44] yolo_conv_2/conv2d_69 bn
# I0621 05:39:48.832628 139900820113216 utils.py:44] yolo_conv_2/conv2d_70 bn
# I0621 05:39:48.835634 139900820113216 utils.py:44] yolo_conv_2/conv2d_71 bn
# I0621 05:39:48.840554 139900820113216 utils.py:44] yolo_conv_2/conv2d_72 bn
# I0621 05:39:48.842276 139900820113216 utils.py:44] yolo_output_2/conv2d_73 bn
# I0621 05:39:48.848075 139900820113216 utils.py:44] yolo_output_2/conv2d_74 bias
# I0621 05:39:48.849374 139900820113216 convert.py:27] weights loaded
# I0621 05:39:49.704695 139900820113216 convert.py:31] sanity check passed
# I0621 05:39:51.829456 139900820113216 convert.py:34] weights saved

# %%
# !python3 detect.py --image ./data/meme.jpg
# Out:
# 2022-06-21 05:40:08.820302: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:08.820429: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-06-21 05:40:10.480685: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-06-21 05:40:10.518342: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-21 05:40:10.521110: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.61GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-06-21 05:40:10.521517: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:10.521744: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:10.578860: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-06-21 05:40:10.579642: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-06-21 05:40:10.579807: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:10.579895: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusparse.so.10'; dlerror: libcusparse.so.10: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:10.579988: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:10.580021: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-06-21 05:40:10.596557: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-21 05:40:10.606131: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2000179999 Hz
# 2022-06-21 05:40:10.607371: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x12050f0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-06-21 05:40:10.607423: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-06-21 05:40:10.608995: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-06-21 05:40:10.609028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# I0621 05:40:17.550293 140467076282176 detect.py:35] weights loaded
# I0621 05:40:17.550945 140467076282176 detect.py:38] classes loaded
# I0621 05:40:18.721059 140467076282176 detect.py:55] time: 1.1086504459381104
# I0621 05:40:18.721251 140467076282176 detect.py:57] detections:
# I0621 05:40:18.726912 140467076282176 detect.py:59] 	cup, 0.9980730414390564, [0.1426622  0.52777606 0.27184254 0.65748256]
# I0621 05:40:18.728802 140467076282176 detect.py:59] 	person, 0.9976975321769714, [0.28982913 0.09854648 0.95846486 0.9202168 ]
# I0621 05:40:18.730509 140467076282176 detect.py:59] 	laptop, 0.9599869847297668, [-0.01710653  0.39493692  0.5229728   0.7962775 ]
# I0621 05:40:18.732210 140467076282176 detect.py:59] 	apple, 0.9081623554229736, [0.13114461 0.77143586 0.22893354 0.90729535]
# I0621 05:40:18.734066 140467076282176 detect.py:59] 	cell phone, 0.7321375608444214, [0.18850096 0.87569416 0.33501852 0.9422209 ]
# I0621 05:40:18.735771 140467076282176 detect.py:59] 	clock, 0.6700013875961304, [0.4010809  0.21244612 0.49267417 0.35021505]
# I0621 05:40:18.946594 140467076282176 detect.py:66] output saved to: ./output.jpg

# %%
from IPython.display import Image
Image(filename='output.jpg')

# %%
# !python3 tools/export_tfserving.py --output serving/yolov3/1/
# Out:
# 2022-06-21 05:40:38.121395: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:38.121446: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-06-21 05:40:39.782481: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-06-21 05:40:39.819615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-21 05:40:39.822623: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.61GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-06-21 05:40:39.823080: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:39.823326: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:39.879658: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-06-21 05:40:39.880211: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-06-21 05:40:39.880347: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:39.880418: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusparse.so.10'; dlerror: libcusparse.so.10: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:39.880498: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory
# 2022-06-21 05:40:39.880521: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-06-21 05:40:39.880852: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-21 05:40:39.893602: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2000179999 Hz
# 2022-06-21 05:40:39.894013: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x122c6f0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-06-21 05:40:39.894048: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-06-21 05:40:39.895849: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-06-21 05:40:39.895875: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# I0621 05:40:46.757008 139851104851776 export_tfserving.py:32] weights loaded
# 2022-06-21 05:41:08.174320: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: serving/yolov3/1/assets
# I0621 05:41:38.920346 139851104851776 builder_impl.py:774] Assets written to: serving/yolov3/1/assets
# I0621 05:41:40.263729 139851104851776 export_tfserving.py:35] model saved to: serving/yolov3/1/
# I0621 05:41:58.288338 139851104851776 export_tfserving.py:39] {'yolo_nms_3': TensorSpec(shape=(1,), dtype=tf.int32, name='yolo_nms_3'), 'yolo_nms': TensorSpec(shape=(1, None, 4), dtype=tf.float32, name='yolo_nms'), 'yolo_nms_2': TensorSpec(shape=(1, None), dtype=tf.int64, name='yolo_nms_2'), 'yolo_nms_1': TensorSpec(shape=(1, None), dtype=tf.float32, name='yolo_nms_1')}
# I0621 05:41:58.288945 139851104851776 export_tfserving.py:42] classes loaded
# I0621 05:41:59.994544 139851104851776 export_tfserving.py:53] time: 1.6565454006195068
# I0621 05:41:59.994727 139851104851776 export_tfserving.py:55] detections:
# I0621 05:41:59.996760 139851104851776 export_tfserving.py:57] 	person, 0.9997696280479431, [0.06754467 0.03718692 0.967988   0.9650753 ]
# I0621 05:41:59.998169 139851104851776 export_tfserving.py:57] 	chair, 0.9255475997924805, [0.01851871 0.34200275 0.17385134 0.62783295]

# %%
# !saved_model_cli show --dir serving/yolov3/1/ --tag_set serve --signature_def serving_default
# Out:
# 2022-06-21 05:42:33.897600: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-06-21 05:42:33.897653: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# The given SavedModel SignatureDef contains the following input(s):
#   inputs['input'] tensor_info:
#       dtype: DT_FLOAT
#       shape: (-1, -1, -1, 3)
#       name: serving_default_input:0
# The given SavedModel SignatureDef contains the following output(s):
#   outputs['yolo_nms'] tensor_info:
#       dtype: DT_FLOAT
#       shape: (1, -1, 4)
#       name: StatefulPartitionedCall:0
#   outputs['yolo_nms_1'] tensor_info:
#       dtype: DT_FLOAT
#       shape: (1, -1)
#       name: StatefulPartitionedCall:1
#   outputs['yolo_nms_2'] tensor_info:
#       dtype: DT_INT64
#       shape: (1, -1)
#       name: StatefulPartitionedCall:2
#   outputs['yolo_nms_3'] tensor_info:
#       dtype: DT_INT32
#       shape: (1)
#       name: StatefulPartitionedCall:3
# Method name is: tensorflow/serving/predict
