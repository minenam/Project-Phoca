# %%
# !git clone https://github.com/zzh8829/yolov3-tf2
# %cd yolov3-tf2/
# !pip install -r requirements-gpu.txt
# Out:
# [WinError 2] 지정된 파일을 찾을 수 없습니다: 'yolov3-tf2/'
# c:\Users\eunhy\OneDrive\Desktop\elice-ai-track\ai-project\ai\object-detection\yolov3-tf2
# Obtaining file:///C:/Users/eunhy/OneDrive/Desktop/elice-ai-track/ai-project/ai/object-detection/yolov3-tf2 (from -r requirements-gpu.txt (line 6))
# Collecting tensorflow-gpu==2.5.1
#   Using cached tensorflow_gpu-2.5.1-cp39-cp39-win_amd64.whl (422.7 MB)
# Collecting opencv-python>=4.2.0.32
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Requirement already satisfied: lxml in c:\users\eunhy\anaconda3\lib\site-packages (from -r requirements-gpu.txt (line 3)) (4.6.3)
# Requirement already satisfied: tqdm in c:\users\eunhy\anaconda3\lib\site-packages (from -r requirements-gpu.txt (line 4)) (4.62.3)
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.15.0-py3-none-any.whl (132 kB)
# Collecting six~=1.15.0
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Collecting astunparse~=1.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# bokeh 2.4.1 requires typing-extensions>=3.10.0, but you have typing-extensions 3.7.4.3 which is incompatible.
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting h5py~=3.1.0
#   Using cached h5py-3.1.0-cp39-cp39-win_amd64.whl (2.7 MB)
# Collecting termcolor~=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting typing-extensions~=3.7.4
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting tensorboard~=2.5
#   Using cached tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting grpcio~=1.34.0
#   Using cached grpcio-1.34.1-cp39-cp39-win_amd64.whl (2.9 MB)
# Requirement already satisfied: wheel~=0.35 in c:\users\eunhy\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (0.37.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\eunhy\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.12.1)
# Collecting numpy~=1.19.2
#   Using cached numpy-1.19.5-cp39-cp39-win_amd64.whl (13.3 MB)
# Collecting keras-nightly~=2.5.0.dev
#   Using cached keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-4.21.1-cp39-cp39-win_amd64.whl (524 kB)
# Requirement already satisfied: colorama in c:\users\eunhy\anaconda3\lib\site-packages (from tqdm->-r requirements-gpu.txt (line 4)) (0.4.4)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\eunhy\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (2.0.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\eunhy\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (2.26.0)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.8.0-py2.py3-none-any.whl (164 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.7-py3-none-any.whl (97 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting protobuf>=3.9.2
#   Using cached protobuf-3.19.4-cp39-cp39-win_amd64.whl (895 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\eunhy\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (58.0.4)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.8-py3-none-any.whl (39 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\eunhy\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\eunhy\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (3.6.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eunhy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eunhy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\eunhy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\eunhy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.1->-r requirements-gpu.txt (line 1)) (2.0.4)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=94f6c74372c2428971407acf0da031b384fac033c2863fd66aff683aaf140276
#   Stored in directory: c:\users\eunhy\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# Installing collected packages: pyasn1, six, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, tensorboard-plugin-wit, tensorboard-data-server, protobuf, numpy, markdown, grpcio, google-auth-oauthlib, absl-py, typing-extensions, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras-nightly, h5py, google-pasta, gast, flatbuffers, astunparse, yolov3-tf2, tensorflow-gpu, opencv-python
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.2.1
#     Uninstalling h5py-3.2.1:
#       Successfully uninstalled h5py-3.2.1
#   Running setup.py develop for yolov3-tf2
# Successfully installed absl-py-0.15.0 astunparse-1.6.3 cachetools-5.2.0 flatbuffers-1.12 gast-0.4.0 google-auth-2.8.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.34.1 h5py-3.1.0 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 markdown-3.3.7 numpy-1.19.5 oauthlib-3.2.0 opencv-python-4.6.0.66 opt-einsum-3.3.0 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.8 six-1.15.0 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-estimator-2.5.0 tensorflow-gpu-2.5.1 termcolor-1.1.0 typing-extensions-3.7.4.3 yolov3-tf2-0.1

# %%
# !ls

import tensorflow as tf
tf.__version__
# Out:
# 'ls'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# '2.5.1'

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O data/yolov3.weights
# !python convert.py
# Out:
# Model: "yolov3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None, None,  0
# __________________________________________________________________________________________________
# yolo_darknet (Functional)       ((None, None, None,  40620640    input[0][0]
# __________________________________________________________________________________________________
# yolo_conv_0 (Functional)        (None, None, None, 5 11024384    yolo_darknet[0][2]
# __________________________________________________________________________________________________
# yolo_conv_1 (Functional)        (None, None, None, 2 2957312     yolo_conv_0[0][0]
#                                                                  yolo_darknet[0][1]
# __________________________________________________________________________________________________
# yolo_conv_2 (Functional)        (None, None, None, 1 741376      yolo_conv_1[0][0]
#                                                                  yolo_darknet[0][0]
# __________________________________________________________________________________________________
# yolo_output_0 (Functional)      (None, None, None, 3 4984063     yolo_conv_0[0][0]
# __________________________________________________________________________________________________
# yolo_output_1 (Functional)      (None, None, None, 3 1312511     yolo_conv_1[0][0]
# __________________________________________________________________________________________________
# yolo_output_2 (Functional)      (None, None, None, 3 361471      yolo_conv_2[0][0]
# __________________________________________________________________________________________________
# yolo_boxes_0 (Lambda)           ((None, None, None,  0           yolo_output_0[0][0]
# __________________________________________________________________________________________________
# yolo_boxes_1 (Lambda)           ((None, None, None,  0           yolo_output_1[0][0]
# __________________________________________________________________________________________________
# yolo_boxes_2 (Lambda)           ((None, None, None,  0           yolo_output_2[0][0]
# __________________________________________________________________________________________________
# yolo_nms (Lambda)               ((1, None, 4), (1, N 0           yolo_boxes_0[0][0]
#                                                                  yolo_boxes_0[0][1]
#                                                                  yolo_boxes_0[0][2]
#                                                                  yolo_boxes_1[0][0]
#                                                                  yolo_boxes_1[0][1]
#                                                                  yolo_boxes_1[0][2]
# 2022-06-22 15:55:01.776752: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-06-22 15:55:01.777019: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-06-22 15:55:04.118830: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-06-22 15:55:04.119030: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-22 15:55:04.123310: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: ���ױ׷�
# 2022-06-22 15:55:04.123546: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: ���ױ׷�
# 2022-06-22 15:55:04.135414: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From c:\Users\eunhy\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# W0622 15:55:06.356398 23192 deprecation.py:528] From c:\Users\eunhy\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# I0622 15:55:06.377428 23192 convert.py:24] model created
# I0622 15:55:06.378429 23192 utils.py:44] yolo_darknet/conv2d bn
# I0622 15:55:06.380429 23192 utils.py:44] yolo_darknet/conv2d_1 bn
# I0622 15:55:06.381598 23192 utils.py:44] yolo_darknet/conv2d_2 bn
# I0622 15:55:06.382814 23192 utils.py:44] yolo_darknet/conv2d_3 bn
# I0622 15:55:06.383813 23192 utils.py:44] yolo_darknet/conv2d_4 bn
# I0622 15:55:06.385813 23192 utils.py:44] yolo_darknet/conv2d_5 bn
# I0622 15:55:06.386813 23192 utils.py:44] yolo_darknet/conv2d_6 bn
# I0622 15:55:06.388844 23192 utils.py:44] yolo_darknet/conv2d_7 bn
# I0622 15:55:06.389880 23192 utils.py:44] yolo_darknet/conv2d_8 bn
# I0622 15:55:06.390885 23192 utils.py:44] yolo_darknet/conv2d_9 bn
# I0622 15:55:06.393884 23192 utils.py:44] yolo_darknet/conv2d_10 bn
# I0622 15:55:06.708122 23192 utils.py:44] yolo_darknet/conv2d_50 bn
# I0622 15:55:06.714188 23192 utils.py:44] yolo_darknet/conv2d_51 bn
# I0622 15:55:06.755855 23192 utils.py:44] yolo_conv_0/conv2d_52 bn
# I0622 15:55:06.760924 23192 utils.py:44] yolo_conv_0/conv2d_53 bn
# I0622 15:55:06.803795 23192 utils.py:44] yolo_conv_0/conv2d_54 bn
# I0622 15:55:06.809860 23192 utils.py:44] yolo_conv_0/conv2d_55 bn
# I0622 15:55:06.854362 23192 utils.py:44] yolo_conv_0/conv2d_56 bn
# I0622 15:55:06.860179 23192 utils.py:44] yolo_output_0/conv2d_57 bn
# I0622 15:55:06.903493 23192 utils.py:44] yolo_output_0/conv2d_58 bias
# I0622 15:55:06.906035 23192 utils.py:44] yolo_conv_1/conv2d_59 bn
# I0622 15:55:06.908053 23192 utils.py:44] yolo_conv_1/conv2d_60 bn
# I0622 15:55:06.910048 23192 utils.py:44] yolo_conv_1/conv2d_61 bn
# I0622 15:55:06.916111 23192 utils.py:44] yolo_conv_1/conv2d_62 bn
# I0622 15:55:06.918046 23192 utils.py:44] yolo_conv_1/conv2d_63 bn
# I0622 15:55:06.925020 23192 utils.py:44] yolo_conv_1/conv2d_64 bn
# I0622 15:55:06.925950 23192 utils.py:44] yolo_output_1/conv2d_65 bn
# I0622 15:55:06.933015 23192 utils.py:44] yolo_output_1/conv2d_66 bias
# I0622 15:55:06.933948 23192 utils.py:44] yolo_conv_2/conv2d_67 bn
# I0622 15:55:06.934949 23192 utils.py:44] yolo_conv_2/conv2d_68 bn
# I0622 15:55:06.935977 23192 utils.py:44] yolo_conv_2/conv2d_69 bn
# I0622 15:55:06.937553 23192 utils.py:44] yolo_conv_2/conv2d_70 bn
# I0622 15:55:06.938642 23192 utils.py:44] yolo_conv_2/conv2d_71 bn
# I0622 15:55:06.940645 23192 utils.py:44] yolo_conv_2/conv2d_72 bn
# I0622 15:55:06.941630 23192 utils.py:44] yolo_output_2/conv2d_73 bn
# I0622 15:55:06.943645 23192 utils.py:44] yolo_output_2/conv2d_74 bias
# I0622 15:55:06.944606 23192 convert.py:27] weights loaded
# I0622 15:55:07.516340 23192 convert.py:31] sanity check passed
# I0622 15:55:17.971339 23192 convert.py:34] weights saved

# %%
# !python detect.py --image ./data/meme.jpg
# Out:
# 2022-06-22 15:55:36.709118: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-06-22 15:55:36.709302: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-06-22 15:55:38.499421: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-06-22 15:55:38.499573: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-22 15:55:38.502247: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: ���ױ׷�
# 2022-06-22 15:55:38.502456: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: ���ױ׷�
# 2022-06-22 15:55:38.512209: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From c:\Users\eunhy\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# W0622 15:55:40.269146 22140 deprecation.py:528] From c:\Users\eunhy\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# I0622 15:55:41.724994 22140 detect.py:35] weights loaded
# I0622 15:55:41.738292 22140 detect.py:38] classes loaded
# I0622 15:55:43.604817 22140 detect.py:55] time: 1.8078041076660156
# I0622 15:55:43.604817 22140 detect.py:57] detections:
# I0622 15:55:43.611940 22140 detect.py:59] 	cup, 0.9980730414390564, [0.1426622  0.52777606 0.27184254 0.65748256]
# I0622 15:55:43.615939 22140 detect.py:59] 	person, 0.9976975917816162, [0.28982916 0.09854648 0.95846486 0.9202168 ]
# I0622 15:55:43.618939 22140 detect.py:59] 	laptop, 0.9599869847297668, [-0.01710653  0.39493692  0.5229728   0.7962775 ]
# I0622 15:55:43.621693 22140 detect.py:59] 	apple, 0.9081623554229736, [0.13114461 0.77143586 0.22893354 0.90729535]
# I0622 15:55:43.624694 22140 detect.py:59] 	cell phone, 0.7321375608444214, [0.18850096 0.87569416 0.33501852 0.9422209 ]
# I0622 15:55:43.626692 22140 detect.py:59] 	clock, 0.6700013875961304, [0.4010809  0.21244612 0.49267417 0.35021505]
# I0622 15:55:43.628691 22140 detect.py:59] 	cup, 0.5366387963294983, [0.1508823  0.52855617 0.25541586 0.66439587]
# I0622 15:55:43.631692 22140 detect.py:59] 	chair, 0.5001125335693359, [0.2950731  0.30677184 0.9998861  0.9955944 ]
# I0622 15:55:44.479291 22140 detect.py:66] output saved to: ./output.jpg

# %%
from IPython.display import Image
Image(filename='output.jpg')

# %%
# !python tools/export_tfserving.py --output ../saved_model/
# Out:
# 2022-06-22 15:56:11.923060: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-06-22 15:56:11.923350: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-06-22 15:56:13.741790: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-06-22 15:56:13.742036: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-22 15:56:13.744443: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: ���ױ׷�
# 2022-06-22 15:56:13.744629: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: ���ױ׷�
# 2022-06-22 15:56:13.744907: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From c:\Users\eunhy\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# W0622 15:56:15.480208 16984 deprecation.py:528] From c:\Users\eunhy\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# I0622 15:56:16.550327 16984 export_tfserving.py:32] weights loaded
# 2022-06-22 15:56:31.418281: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# c:\Users\eunhy\anaconda3\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# W0622 15:56:49.738616 16984 save.py:1239] FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: ../saved_model/assets
# I0622 15:57:00.446330 16984 builder_impl.py:774] Assets written to: ../saved_model/assets
# I0622 15:57:03.314025 16984 export_tfserving.py:35] model saved to: ../saved_model/
# I0622 15:57:18.851200 16984 export_tfserving.py:39] {'yolo_nms_1': TensorSpec(shape=(1, None), dtype=tf.float32, name='yolo_nms_1'), 'yolo_nms': TensorSpec(shape=(1, None, 4), dtype=tf.float32, name='yolo_nms'), 'yolo_nms_3': TensorSpec(shape=(1,), dtype=tf.int32, name='yolo_nms_3'), 'yolo_nms_2': TensorSpec(shape=(1, None), dtype=tf.int64, name='yolo_nms_2')}
# I0622 15:57:18.852219 16984 export_tfserving.py:42] classes loaded
# 2022-06-22 15:57:18.885038: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# I0622 15:57:20.335090 16984 export_tfserving.py:53] time: 1.461237907409668
# I0622 15:57:20.335090 16984 export_tfserving.py:55] detections:
# I0622 15:57:20.339090 16984 export_tfserving.py:57] 	person, 0.9997696876525879, [0.06754467 0.03718686 0.967988   0.9650754 ]
# I0622 15:57:20.341831 16984 export_tfserving.py:57] 	chair, 0.9255475997924805, [0.01851871 0.34200278 0.17385134 0.6278329 ]

# %%
# !saved_model_cli show --dir ../saved_model/ --tag_set serve --signature_def serving_default
# Out:
# The given SavedModel SignatureDef contains the following input(s):
#   inputs['input'] tensor_info:
#       dtype: DT_FLOAT
#       shape: (-1, -1, -1, 3)
#       name: serving_default_input:0
# The given SavedModel SignatureDef contains the following output(s):
#   outputs['yolo_nms'] tensor_info:
#       dtype: DT_FLOAT
#       shape: (1, -1, 4)
#       name: StatefulPartitionedCall:0
#   outputs['yolo_nms_1'] tensor_info:
#       dtype: DT_FLOAT
#       shape: (1, -1)
#       name: StatefulPartitionedCall:1
#   outputs['yolo_nms_2'] tensor_info:
#       dtype: DT_INT64
#       shape: (1, -1)
#       name: StatefulPartitionedCall:2
#   outputs['yolo_nms_3'] tensor_info:
#       dtype: DT_INT32
#       shape: (1)
#       name: StatefulPartitionedCall:3
# Method name is: tensorflow/serving/predict
# 2022-06-22 15:57:33.865213: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-06-22 15:57:33.865465: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
